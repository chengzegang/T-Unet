# %%
from os import path, listdir, mkdir
from pydub import AudioSegment
from pydub.playback import play
import numpy as np
import stempeg
from IPython import display
from scipy.io import wavfile
from scipy import signal

# %%
files = listdir('musdb18/train/')
files = ['musdb18/train/' + el for el in files]
files[0]
# Out:
# 'musdb18/train/A Classic Education - NightOwl.stem.mp4'

# %%
test_audio, test_sample_rate = stempeg.read_stems(files[0])

# %%
test_mix = test_audio[0, :,  0]
test_vocal = test_audio[4,:, 0]

# %%
test_mix = signal.resample(test_mix, int(8000 / sample_rate * len(test_mix)))
test_vocal = signal.resample(test_vocal, int(8000 / sample_rate * len(test_vocal)))
test_mix = test_mix[0: 24000]

# %%
test_mix.shape
# Out:
# (24000,)

# %%
display.Audio(test_mix, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display.Audio(test_vocal, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for i, f in enumerate(files):
    audio, sample_rate = stempeg.read_stems(files[0], sample_rate=8000)
    mix = audio[0, :, 0]
    vocal = audio[4, :, 0]
    size = round(len(mix) / 24000)
    for j in range(size):
        x = mix[24000 * j : 24000 * (j + 1)]
        y = vocal[24000 * j : 24000 * (j + 1)]
        stempeg.write_audio('songs/mix/mix' + str(i) + '_' + str(j) + '.wav', x, sample_rate=8000)
        stempeg.write_audio('songs/vocal/vocal' + str(i) + '_' + str(j) + '.wav', y, sample_rate=8000)
